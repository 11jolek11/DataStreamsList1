# %% [markdown]
# <a href="https://colab.research.google.com/github/11jolek11/DataStreamsList1/blob/main/List1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np




def generate_bell_data(n=15, a=0, b=10):
    X = np.linspace(a, b, n)
    y = (1/np.sqrt(np.pi)*4)*(np.e**(-0.5*((X-7)/2)**2))
    return X, y

x_data, y_data = generate_bell_data()

plt.plot(x_data, y_data)
plt.scatter(x_data, y_data)
plt.bar(x_data, y_data)
plt.show()

# %%
fig, axis = plt.subplot_mosaic(
    [["A panel", "B panel"],
     ["A panel", "C panel"]]
)

axis["A panel"].plot(x_data, y_data)
axis["B panel"].scatter(x_data, y_data)
axis["C panel"].bar(x_data, y_data)

plt.show()

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='rainbow', edgecolor='none')
ax.set_title('wykresik');
